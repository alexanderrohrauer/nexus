# %%
import pandas as pd
from beanie import init_beanie, PydanticObjectId
from motor.motor_asyncio import AsyncIOMotorClient
from app.models import models
import app.utils.pandas_utils as pu
from app.models.researchers import Researcher
from app.models.works import Work

# %%
client = AsyncIOMotorClient("mongodb://localhost:27017")
await init_beanie(database=client["nexus_dev"], document_models=models)

# %%
works = await Work.find(Work.authors.id == PydanticObjectId("675729251fc3e5ed73dd6f53")).to_list()
df = pd.DataFrame([w.model_dump() for w in works]).set_index("id")

# %%
df
# Out:
#                                                           uuid  \
# id
# 675729261fc3e5ed73dd6fd9  8d611a7e-cea6-42f4-8830-dcefc058bf22
# 6757292a1fc3e5ed73dd717d  40097f96-8f8d-4ae1-934b-903ef4cc8065
#
#                                      imported_at manually_updated_at  \
# id
# 675729261fc3e5ed73dd6fd9 2024-12-09 18:30:14.151                None
# 6757292a1fc3e5ed73dd717d 2024-12-09 18:30:17.507                None
#
#                                                                 external_id  \
# id
# 675729261fc3e5ed73dd6fd9  {'openalex': None, 'orcid': None, 'dblp': '268...
# 6757292a1fc3e5ed73dd717d  {'openalex': None, 'orcid': None, 'dblp': '290...
#
#                                                                       title  \
# id
# 675729261fc3e5ed73dd6fd9  Model-driven engineering support for social an...
# 6757292a1fc3e5ed73dd717d  Considerations about quality in model-driven e...
#
#                                                                        type  \
# id
# 675729261fc3e5ed73dd6fd9  {'openalex': None, 'orcid': None, 'dblp': 'Con...
# 6757292a1fc3e5ed73dd717d  {'openalex': None, 'orcid': None, 'dblp': 'Jou...
#
#                           publication_year publication_date keywords  \
# id
# 675729261fc3e5ed73dd6fd9              2019             None     None
# 6757292a1fc3e5ed73dd717d              2018             None     None
#
#                                                                     authors  \
# id
# 675729261fc3e5ed73dd6fd9  [<beanie.odm.fields.Link object at 0x1082886d0...
# 6757292a1fc3e5ed73dd717d  [<beanie.odm.fields.Link object at 0x10cb68190...
#
#                          language  open_access openalex_meta orcid_meta  \
# id
# 675729261fc3e5ed73dd6fd9     None        False          None       None
# 6757292a1fc3e5ed73dd717d     None        False          None       None
#
#                                                                   dblp_meta
# id
# 675729261fc3e5ed73dd6fd9  {'@score': '3', '@id': '2688909', 'info': {'au...
# 6757292a1fc3e5ed73dd717d  {'@score': '3', '@id': '2906511', 'info': {'au...

# %%
works = await Work.find({"authors.full_name": "Manuel Wimmer"}, fetch_links=True).to_list()
df = pu.read_from_beanie(works)

# %%
df
# Out:
#                          id                                  uuid  \
# 0  6757292a1fc3e5ed73dd717e  ae331765-6a0d-48b9-941d-4cd4e7a60d8c
# 1  675729ba1fc3e5ed73dd755b  90df6963-aae3-4f2b-9028-39b2d897767b
#
#               imported_at manually_updated_at  \
# 0 2024-12-09 18:30:17.508                None
# 1 2024-12-09 18:32:42.015                None
#
#                                          external_id  \
# 0  {'openalex': None, 'orcid': None, 'dblp': '291...
# 1  {'openalex': 'W4404510229', 'orcid': None, 'db...
#
#                                                title  \
# 0  A Model-Driven Engineering Workbench for CAEX ...
# 1  From single-objective to multi-objective reinf...
#
#                                                 type  publication_year  \
# 0  {'openalex': None, 'orcid': None, 'dblp': 'Jou...              2018
# 1  {'openalex': 'article', 'orcid': None, 'dblp':...              2024
#
#   publication_date                                           keywords  \
# 0             None                                               None
# 1       2024-11-19  [Model Transformation, Testing-Effort Dependen...
#
#                                              authors language  open_access  \
# 0  [{'id': 675729291fc3e5ed73dd7107, 'uuid': e957...     None        False
# 1  [{'id': 675729b91fc3e5ed73dd751f, 'uuid': aa85...       en         True
#
#                                        openalex_meta orcid_meta  \
# 0                                               None       None
# 1  {'id': 'https://openalex.org/W4404510229', 'do...       None
#
#                                            dblp_meta
# 0  {'@score': '3', '@id': '2917982', 'info': {'au...
# 1                                               None
